# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 1000
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.model_selection import permutation_test_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import pickle
import os

import sys
sys.path.append("../../code")
import interpretability

# %%
response_var = "responder"
response_var_cap = "Responder"

# %%
# load in dynamix data
df_dynamix = pd.read_pickle('../../data/dynamix_ec_std_all.pkl')
print("Dynamix dataframe shape:", df_dynamix.shape) # 128 subjects, 1 + 80 (num_weights)

# pca on dynamix data to get top 5 components
numeric_df = df_dynamix.select_dtypes(include='number')

# apply pca
pca = PCA(n_components=5)  # keep top 5 components
principal_components = pca.fit_transform(numeric_df)

# create a DataFrame for the top 5 components
pca_df_dynamix = pd.DataFrame(
    principal_components, 
    columns=[f'dyna_PC{i+1}' for i in range(5)]
)

# keep participants_ID
pca_df_dynamix['participants_ID'] = df_dynamix['participants_ID'].values

print("Top 5 PCs dataframe shape:", pca_df_dynamix.shape)
print(pca_df_dynamix.head())

# see which features contribute to each PC
loadings = pd.DataFrame(pca.components_, columns=numeric_df.columns, index=[f'PC{i+1}' for i in range(5)])
for pc in loadings.index:
    top = loadings.loc[pc].abs().sort_values(ascending=False).head(5)
    print(f"\n{pc} top features:")
    print(pd.DataFrame({'Feature': top.index, 'Loading': loadings.loc[pc, top.index].values}))
# Out:
# Dynamix dataframe shape: (128, 81)
# Top 5 PCs dataframe shape: (128, 6)
#    dyna_PC1  dyna_PC2  dyna_PC3  dyna_PC4  dyna_PC5 participants_ID
# 0  0.024507  0.020677  0.021783 -0.005771 -0.006395    sub-87999321
# 1 -0.010326  0.001470 -0.008291  0.001181  0.000766    sub-88000181
# 2 -0.015232  0.013399 -0.008536 -0.000912  0.002079    sub-88000313
# 3 -0.020834  0.009630 -0.008517 -0.005561  0.001888    sub-88000489
# 4  0.005223 -0.017595  0.004524  0.014130 -0.000767    sub-88000533
#
# PC1 top features:
#              Feature   Loading
# 0  dynamix_ec_std_51  0.551342
# 1  dynamix_ec_std_26  0.423790
# 2  dynamix_ec_std_57  0.376357
# 3  dynamix_ec_std_53  0.247710
# 4  dynamix_ec_std_19  0.246373
#
# PC2 top features:
#              Feature   Loading
# 0  dynamix_ec_std_57  0.794278
# 1  dynamix_ec_std_45 -0.355530
# 2   dynamix_ec_std_3 -0.355028
# 3   dynamix_ec_std_4 -0.131798
# 4  dynamix_ec_std_79 -0.123170
#
# PC3 top features:
#              Feature   Loading
# 0  dynamix_ec_std_45  0.509781
# 1  dynamix_ec_std_51 -0.492956
# 2  dynamix_ec_std_57  0.412979
# 3   dynamix_ec_std_3  0.319566
# 4   dynamix_ec_std_4  0.242991
#
# PC4 top features:
#              Feature   Loading
# 0   dynamix_ec_std_4  0.759165
# 1  dynamix_ec_std_29 -0.359765
# 2   dynamix_ec_std_7  0.350904
# 3   dynamix_ec_std_3 -0.245328
# 4  dynamix_ec_std_79 -0.193307
#
# PC5 top features:
#              Feature   Loading
# 0  dynamix_ec_std_29  0.811480
# 1  dynamix_ec_std_45 -0.313147
# 2   dynamix_ec_std_4  0.297247
# 3  dynamix_ec_std_79  0.224410
# 4   dynamix_ec_std_3 -0.218131

# %%
# load in bandpower data
df_bandpower = pd.read_pickle('../../data/mdd_rtms_bandpower_all.pkl')
print("Bandpower dataframe shape:", df_bandpower.shape) # 128 subjects, 1 + (ec/eo) x num_electrodes x num_bands

# pca on bandpower data to get top 5 components
numeric_df = df_bandpower.select_dtypes(include='number')

# apply pca
pca = PCA(n_components=5)  # keep top 5 components
principal_components = pca.fit_transform(numeric_df)

# create a DataFrame for the top 5 components
pca_df_bandpower = pd.DataFrame(
    principal_components, 
    columns=[f'bp_PC{i+1}' for i in range(5)]
)

# keep participants_ID
pca_df_bandpower['participants_ID'] = df_bandpower['participants_ID'].values

print("Top 5 PCs dataframe shape:", pca_df_bandpower.shape)
print(pca_df_bandpower.head())

# see which features contribute to each PC
loadings = pd.DataFrame(pca.components_, columns=numeric_df.columns, index=[f'PC{i+1}' for i in range(5)])
for pc in loadings.index:
    top = loadings.loc[pc].abs().sort_values(ascending=False).head(5)
    print(f"\n{pc} top features:")
    print(pd.DataFrame({'Feature': top.index, 'Loading': loadings.loc[pc, top.index].values}))
# Out:
# Bandpower dataframe shape: (128, 365)
# Top 5 PCs dataframe shape: (128, 6)
#      bp_PC1    bp_PC2    bp_PC3    bp_PC4    bp_PC5 participants_ID
# 0  0.456554 -0.218373 -0.069308  0.048824  0.627367    sub-87999321
# 1  0.598108  0.401997 -0.288402  0.420649 -0.222144    sub-88000181
# 2  1.195718  0.422061 -0.032820  0.722472  0.186482    sub-88000313
# 3  1.120544 -0.128459 -0.605335 -0.159502  0.427999    sub-88000489
# 4 -0.829465 -0.841485  0.490047 -0.200865  0.146694    sub-88000533
#
# PC1 top features:
#              Feature   Loading
# 0  EC_O1_alpha_power  0.162492
# 1  EC_Oz_alpha_power  0.159974
# 2  EC_O2_alpha_power  0.153124
# 3  EC_P7_alpha_power  0.137086
# 4  EC_P8_alpha_power  0.135762
#
# PC2 top features:
#               Feature   Loading
# 0   EC_Pz_alpha_power  0.155344
# 1   EC_O2_alpha_power  0.151222
# 2   EC_O1_alpha_power  0.146704
# 3   EC_Oz_alpha_power  0.144447
# 4  EC_CPz_alpha_power  0.135586
#
# PC3 top features:
#               Feature   Loading
# 0  EO_Fp1_delta_power  0.172812
# 1  EO_Fp2_delta_power  0.170623
# 2   EO_Pz_delta_power  0.150348
# 3   EO_F3_delta_power  0.147392
# 4  EO_CPz_delta_power  0.144016
#
# PC4 top features:
#                  Feature   Loading
# 0  EC_CP4_low_beta_power  0.118816
# 1   EC_C4_low_beta_power  0.116121
# 2   EC_P4_low_beta_power  0.115825
# 3  EC_CPz_low_beta_power  0.115807
# 4   EC_P3_low_beta_power  0.115642
#
# PC5 top features:
#                   Feature   Loading
# 0  EC_P7_high_gamma_power  0.142622
# 1  EC_O2_high_gamma_power  0.136375
# 2       EC_O2_alpha_power -0.134580
# 3  EC_Oz_high_gamma_power  0.134045
# 4  EC_O1_high_gamma_power  0.127955

# %% [markdown]
# ### Merge dataframes

# %%
demographic_df = pd.read_csv(f"../../data/final_dataset_{response_var}.csv")
demographic_df.head()
print("Demographic dataframe shape:", demographic_df.shape)

duplicate_ids = demographic_df["participants_ID"].value_counts()
duplicate_ids = duplicate_ids[duplicate_ids > 1].index
demographic_df = demographic_df.drop_duplicates(subset="participants_ID", keep="first")
print("Shape after keeping only first entry for each participant:", demographic_df.shape)

df = pd.merge(pca_df_bandpower, pca_df_dynamix, on='participants_ID', how='inner')
df = pd.merge(df, demographic_df, on='participants_ID', how='inner')
print("Merged dataframe shape:", df.shape)
print(df.head())
# Out:
# Demographic dataframe shape: (230, 114)
# Shape after keeping only first entry for each participant: (215, 114)
# Merged dataframe shape: (144, 124)
#      bp_PC1    bp_PC2    bp_PC3    bp_PC4    bp_PC5 participants_ID  dyna_PC1  \
# 0  0.456554 -0.218373 -0.069308  0.048824  0.627367    sub-87999321  0.024507
# 1  0.598108  0.401997 -0.288402  0.420649 -0.222144    sub-88000181 -0.010326
# 2  1.195718  0.422061 -0.032820  0.722472  0.186482    sub-88000313 -0.015232
# 3  1.120544 -0.128459 -0.605335 -0.159502  0.427999    sub-88000489 -0.020834
# 4 -0.829465 -0.841485  0.490047 -0.200865  0.146694    sub-88000533  0.005223
#
#    dyna_PC2  dyna_PC3  dyna_PC4  ...  ever_used_cigarette  \
# 0  0.020677  0.021783 -0.005771  ...                  0.0
# 1  0.001470 -0.008291  0.001181  ...                  0.0
# 2  0.013399 -0.008536 -0.000912  ...                  1.0
# 3  0.009630 -0.008517 -0.005561  ...                  0.0
# 4 -0.017595  0.004524  0.014130  ...                  1.0
#
#   hours_since_last_cigarette ever_used_coffee hours_since_last_coffee  \
# 0                        NaN              0.0                     NaN
# 1                        NaN              1.0                     9.0
# 2                        9.0              1.0                     9.0
# 3                        NaN              1.0                     5.0
# 4                        8.0              1.0                     9.0
#
#   ever_used_beer hours_since_last_beer ever_used_drugs hours_since_last_drugs  \
# 0            0.0                   NaN             1.0                    0.0
# 1            1.0                  15.0             1.0                    0.0
# 2            0.0                   NaN             1.0                    0.0
# 3            1.0                  13.0             1.0                    0.0
# 4            1.0                  13.0             1.0                    0.0
#
#    hours_since_last_meal  hours_since_last_sleep
# 0                    5.0                     7.0
# 1                    3.0                     7.0
# 2                    3.0                     9.0
# 3                    5.0                     9.0
# 4                    3.0                     5.0
#
# [5 rows x 124 columns]

# %% [markdown]
# ### Preprocessing & splitting

# %%
demographic_cols = ['age', 'gender', 'education', 'BDI_pre', 'ever_used_drugs']
pca_cols = df.filter(regex='PC').columns.tolist()
print(pca_cols)

# construct X
X = df[demographic_cols + pca_cols]
y = df[response_var_cap]

# binary vars float --> str
X = X.copy()
X['gender'] = X['gender'].map({1.0: 'male', 0.0: 'female'})

print("X shape:", X.shape)
print("X columns:", X.columns)
# print("X column datatypes:", X.dtypes)
# print(X.head())
# Out:
# ['bp_PC1', 'bp_PC2', 'bp_PC3', 'bp_PC4', 'bp_PC5', 'dyna_PC1', 'dyna_PC2', 'dyna_PC3', 'dyna_PC4', 'dyna_PC5']
# X shape: (144, 15)
# X columns: Index(['age', 'gender', 'education', 'BDI_pre', 'ever_used_drugs', 'bp_PC1',
#        'bp_PC2', 'bp_PC3', 'bp_PC4', 'bp_PC5', 'dyna_PC1', 'dyna_PC2',
#        'dyna_PC3', 'dyna_PC4', 'dyna_PC5'],
#       dtype='object')

# %%
# construct preprocesser
# decide which encoder to use on each feature
onehot_ftrs = ['gender', 'ever_used_drugs']
std_ftrs = ['age', 'education', 'BDI_pre'] + pca_cols

# one hot pipeline
X['ever_used_drugs'] = X['ever_used_drugs'].fillna(99)
onehot_transformer = Pipeline(steps=[
    ('imputer0', SimpleImputer(strategy='constant')), 
    ('onehot', OneHotEncoder(sparse_output=False, handle_unknown='ignore')),
])

# numeric pipeline with imputation + scaling
numeric_transformer = Pipeline(steps=[
    ('imputer2', SimpleImputer(strategy='median')),  # fills missing values with median
    ('scaler', StandardScaler())                     # scales features
])

# collect all the encoders
preprocessor = ColumnTransformer(
    transformers=[
        ('onehot', onehot_transformer, onehot_ftrs), 
        ('std', numeric_transformer, std_ftrs)])

clf = Pipeline(steps=[('preprocessor', preprocessor)])

# %%
# outer split: stratified split test and other
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42) 
print(X_train_val.shape)
print(X_test.shape)

# inner split: stratified k fold with k = 4 (60-20-20)
inner_split = StratifiedKFold(n_splits=4, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(inner_split.split(X_train_val, y_train_val)):
    print(f"Fold {fold+1}")
    X_train, X_val = X_train_val.iloc[train_idx], X_train_val.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    print("X_train shape:", X_train.shape)
    print("X_val shape:", X_val.shape)
# Out:
# (115, 15)
# (29, 15)
# Fold 1
# X_train shape: (86, 15)
# X_val shape: (29, 15)
# Fold 2
# X_train shape: (86, 15)
# X_val shape: (29, 15)
# Fold 3
# X_train shape: (86, 15)
# X_val shape: (29, 15)
# Fold 4
# X_train shape: (87, 15)
# X_val shape: (28, 15)

# %%
# try preprocessor on the last fold
print("Before preprocessing...")
print("X train:", X_train.shape)
print("X val:", X_val.shape)
print("X test:", X_test.shape, "\n")

X_train_prep = clf.fit_transform(X_train)

# relabel the columns after transformation
onehot_feature_names = clf.named_steps['preprocessor'].named_transformers_['onehot'].get_feature_names_out()
new_feature_names = list(onehot_feature_names) + std_ftrs
print(new_feature_names)

X_train_prep = pd.DataFrame(X_train_prep, columns=new_feature_names)
X_val_prep = pd.DataFrame(clf.transform(X_val), columns=new_feature_names)
X_test_prep = pd.DataFrame(clf.transform(X_test), columns=new_feature_names)

# print number of data points after preprocessing
print("After preprocessing...")
print("X train:", X_train_prep.shape)
print("X val:", X_val_prep.shape)
print("X test:", X_test_prep.shape)
# Out:
# Before preprocessing...
# X train: (87, 15)
# X val: (28, 15)
# X test: (29, 15)
#
# ['gender_female', 'gender_male', 'ever_used_drugs_0.0', 'ever_used_drugs_1.0', 'age', 'education', 'BDI_pre', 'bp_PC1', 'bp_PC2', 'bp_PC3', 'bp_PC4', 'bp_PC5', 'dyna_PC1', 'dyna_PC2', 'dyna_PC3', 'dyna_PC4', 'dyna_PC5']
# After preprocessing...
# X train: (87, 17)
# X val: (28, 17)
# X test: (29, 17)

# %%
# try simple model on data
log_reg = LogisticRegression(solver='saga', max_iter=100000000)
log_reg.fit(X_train_prep, y_train)
y_pred_val = log_reg.predict(X_val_prep)
y_pred_train = log_reg.predict(X_train_prep)
print("Accuracy on validation set:", accuracy_score(y_val,y_pred_val))
print("Accuracy on training set:", accuracy_score(y_train,y_pred_train))
# Out:
# Accuracy on validation set: 0.75
# Accuracy on training set: 0.7586206896551724

# %% [markdown]
# ### Pipeline

# %%
def MLpipe_SKFold(X, y, preprocessor, ML_algo, param_grid, model_name, eval_metric, num_states=5, do_permutation_test=True):
    '''
    Pipeline with:
        Splitting method -- StratifiedKFold
        Evaluation metric -- Depends on input
    '''

    train_scores = []
    test_scores = []
    best_models = []
    cv_scores = []
    perm_scores_list = []
    perm_pvalues = []

    print(f"\n=== Training {model_name} ({eval_metric}) ===")

    for i in range(num_states):
        # Define random state
        random_state = 29*(i+1)
        
        # --- SPLIT ---
        X_other, X_test, y_other, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state) 
        kf = StratifiedKFold(n_splits=4, shuffle=True, random_state=random_state)

        # --- PREPROCES S---
        # Main preprocessor is fed into function as "preprocessor"
        final_scaler = StandardScaler()

        # --- PIPELINE & GRID SEARCH ---
        pipeline = make_pipeline(preprocessor, ML_algo)
        grid = GridSearchCV(pipeline, param_grid=param_grid, cv=kf, scoring=eval_metric, return_train_score=True, n_jobs=-1, verbose=0)
        grid.fit(X_other, y_other)
        results = pd.DataFrame(grid.cv_results_)
        # print("\nGrid search results:\n", results)

        # --- BEST MODEL & SCORES ---
        best_model = grid.best_estimator_
        best_models.append(best_model)
        print(f"Random state {random_state}: {grid.best_params_}")
        
        # train score
        train_score = grid.cv_results_['mean_train_score'][grid.best_index_]
        train_scores.append(train_score)

        # test score
        y_test_pred = best_model.predict(X_test)
        if eval_metric == "accuracy":
            best_test_score = accuracy_score(y_test, y_test_pred)
        elif eval_metric == "precision":
            best_test_score = precision_score(y_test, y_test_pred, average="macro")
        elif eval_metric == "f1_macro":
            best_test_score = f1_score(y_test, y_test_pred, average="macro")
        elif eval_metric == "f1_weighted":
            best_test_score = f1_score(y_test, y_test_pred, average="weighted")
        else:
            raise ValueError("Evaluation metric not handled in this pipeline.") 
        test_scores.append(best_test_score)
       
        # print(f"    Train score: {train_score:.4f} | Test score: {best_test_score:.4f}")

        # --- OPTIONAL PERMUTATION TEST ---
        if do_permutation_test:
            cv_score, perm_scores, p_value = permutation_test_score(
                best_model,
                X_other,
                y_other,
                scoring=eval_metric,
                cv=kf,
                n_permutations=1000,
                random_state=random_state,
                n_jobs=-1
            )
            cv_scores.append(cv_score)
            perm_scores_list.append(perm_scores)
            perm_pvalues.append(p_value)
            # print(f"    Permutation CV score: {cv_score:.4f} | p-value: {p_value:.4f}")
        
    # --- SAVE RESULTS ---
    file_path = os.path.join('../../results/mdd_dyna_bp/', f'{model_name}_{eval_metric}_{response_var}.save')
    with open(file_path, 'wb') as file:
        pickle.dump((best_models, test_scores), file)

    return (
        train_scores,
        test_scores,
        best_models,
        cv_scores if do_permutation_test else None,
        perm_scores_list if do_permutation_test else None,
        perm_pvalues if do_permutation_test else None,
    )

# %%
# define model algorithms and parameter grids
models = {
    'SimpleLogisticRegression': (
        LogisticRegression(solver='saga', max_iter=1000000), {} 
    ),
    'L1LogisticRegression': (
        LogisticRegression(solver='saga', max_iter=1000000),
        {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10],
         'logisticregression__l1_ratio': [1]}
    ),
    'L2LogisticRegression': (
        LogisticRegression(solver='saga', max_iter=1000000),
        {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10],
         'logisticregression__l1_ratio': [0]}
    ),
    'ElasticNet': (
        LogisticRegression(solver='saga', max_iter=100000000),
        {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10],
         'logisticregression__l1_ratio': [0.0001, 0.001, 0.01, 0.1, 1]}
    ),
    'RandomForestClassifier': (
        RandomForestClassifier(random_state=42),
        {'randomforestclassifier__n_estimators': [100],
         'randomforestclassifier__max_depth': [1, 3, 5, 10],
         'randomforestclassifier__max_features': [0.25, 0.5, 0.75, 1.0, None]}
    ),
    'SupportVectorClassifier': (
        SVC(probability=True),
        {'svc__C': [0.001, 0.01, 0.1, 1, 10],
         'svc__gamma': [0.001, 0.01, 0.1],
         'svc__kernel': ['rbf']
        }
    ),
}

# %%
# evaluation metric = accuracy
summary_acc = {}
perm_plot_data = {}
for model_name, (algo, param_grid) in models.items():
    train_scores, test_scores, best_models, cv_scores, perm_scores_list, perm_pvalues = MLpipe_SKFold(X, y, preprocessor, algo, param_grid, model_name, 'accuracy')

    # clean print of scores
    train_scores_clean = [round(float(s), 4) for s in train_scores]
    test_scores_clean = [round(float(s), 4) for s in test_scores]
    cv_scores_clean = [round(float(s), 4) for s in cv_scores]
    perm_pvalues_clean = [round(float(p), 4) for p in perm_pvalues]

    print("\nTrain Scores:", train_scores_clean)
    print("Test Scores:", test_scores_clean)
    print("Permuation CV Scores:", cv_scores_clean)
    print("Permutation Test p-values:", perm_pvalues_clean)

    summary_acc[model_name] = (
        np.mean(train_scores),
        np.mean(test_scores),
        np.std(test_scores),
        np.mean(cv_scores),
        np.mean([np.mean(p) for p in perm_scores_list]),
        np.std([np.mean(p) for p in perm_scores_list]),
        np.mean(perm_pvalues)
    )

    perm_plot_data[model_name] = (cv_scores, perm_scores_list, perm_pvalues)

# display the summary
print("\n=== Summary of Results ===")
mean_scores = []
stddev_scores = []
algorithms = []

for model_name, (mean_train, mean_test, std_test, mean_cv, mean_perm, std_perm, mean_pvalue) in summary_acc.items():
    print(
        f"{model_name}: Mean train score = {mean_train:.4f}, "
        f"Mean test score = {mean_test:.4f}, "
        f"Mean CV score = {mean_cv:.4f}, "
        f"Permutation scores = {mean_perm:.4f} +/- {std_perm:.4f}, "
        f"Mean p-value = {mean_pvalue:.4f}"
    )

    algorithms.append(model_name)
    mean_scores.append(mean_test)
    stddev_scores.append(std_test)
# Out:
# === Training SimpleLogisticRegression (accuracy) ===
# Random state 29: {}
# Random state 58: {}
# Random state 87: {}
# Random state 116: {}
# Random state 145: {}
#
# Train Scores: [0.8001, 0.8057, 0.8232, 0.8174, 0.7797]
# Test Scores: [0.7241, 0.7586, 0.6897, 0.7241, 0.8276]
# Permuation CV Scores: [0.6952, 0.6696, 0.7657, 0.705, 0.669]
# Permutation Test p-values: [0.0639, 0.2108, 0.002, 0.036, 0.2617]
#
# === Training L1LogisticRegression (accuracy) ===
# Random state 29: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 1}
# Random state 58: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 1}
# Random state 87: {'logisticregression__C': 1, 'logisticregression__l1_ratio': 1}
# Random state 116: {'logisticregression__C': 1, 'logisticregression__l1_ratio': 1}
# Random state 145: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 1}
#
# Train Scores: [0.7044, 0.7044, 0.8116, 0.8058, 0.7044]
# Test Scores: [0.6897, 0.6897, 0.6207, 0.7586, 0.6897]
# Permuation CV Scores: [0.7044, 0.7044, 0.7478, 0.714, 0.7044]
# Permutation Test p-values: [1.0, 1.0, 0.006, 0.026, 1.0]
#
# === Training L2LogisticRegression (accuracy) ===
# Random state 29: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 0}
# Random state 58: {'logisticregression__C': 0.1, 'logisticregression__l1_ratio': 0}
# Random state 87: {'logisticregression__C': 0.1, 'logisticregression__l1_ratio': 0}
# Random state 116: {'logisticregression__C': 0.1, 'logisticregression__l1_ratio': 0}
# Random state 145: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 0}
#
# Train Scores: [0.7044, 0.797, 0.7884, 0.7682, 0.7044]
# Test Scores: [0.6897, 0.7931, 0.6207, 0.7586, 0.6897]
# Permuation CV Scores: [0.7044, 0.7214, 0.7737, 0.722, 0.7044]
# Permutation Test p-values: [1.0, 0.045, 0.001, 0.027, 1.0]
#
# === Training ElasticNet (accuracy) ===
# Random state 29: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 0.0001}
# Random state 58: {'logisticregression__C': 0.1, 'logisticregression__l1_ratio': 0.1}
# Random state 87: {'logisticregression__C': 0.1, 'logisticregression__l1_ratio': 0.1}
# Random state 116: {'logisticregression__C': 1, 'logisticregression__l1_ratio': 0.1}
# Random state 145: {'logisticregression__C': 0.001, 'logisticregression__l1_ratio': 0.0001}
#
# Train Scores: [0.7044, 0.7796, 0.7856, 0.8232, 0.7044]
# Test Scores: [0.6897, 0.7586, 0.6552, 0.7241, 0.6897]
# Permuation CV Scores: [0.7044, 0.7303, 0.7737, 0.7226, 0.7044]
# Permutation Test p-values: [1.0, 0.022, 0.001, 0.01, 1.0]
#
# === Training RandomForestClassifier (accuracy) ===
# Random state 29: {'randomforestclassifier__max_depth': 1, 'randomforestclassifier__max_features': 0.75, 'randomforestclassifier__n_estimators': 100}
# Random state 58: {'randomforestclassifier__max_depth': 5, 'randomforestclassifier__max_features': 0.75, 'randomforestclassifier__n_estimators': 100}
# Random state 87: {'randomforestclassifier__max_depth': 10, 'randomforestclassifier__max_features': 0.25, 'randomforestclassifier__n_estimators': 100}
# Random state 116: {'randomforestclassifier__max_depth': 5, 'randomforestclassifier__max_features': 0.75, 'randomforestclassifier__n_estimators': 100}
# Random state 145: {'randomforestclassifier__max_depth': 1, 'randomforestclassifier__max_features': 0.25, 'randomforestclassifier__n_estimators': 100}
#
# Train Scores: [0.7507, 0.9855, 1.0, 0.9913, 0.7044]
# Test Scores: [0.6897, 0.7241, 0.6207, 0.6897, 0.6897]
# Permuation CV Scores: [0.7217, 0.7204, 0.7648, 0.7223, 0.7044]
# Permutation Test p-values: [0.03, 0.024, 0.002, 0.023, 0.9131]
#
# === Training SupportVectorClassifier (accuracy) ===
# Random state 29: {'svc__C': 0.001, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'}
# Random state 58: {'svc__C': 0.001, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'}
# Random state 87: {'svc__C': 10, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# Random state 116: {'svc__C': 10, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
# Random state 145: {'svc__C': 0.001, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'}
#
# Train Scores: [0.7044, 0.7044, 0.8492, 0.8465, 0.7044]
# Test Scores: [0.6897, 0.6897, 0.6552, 0.7241, 0.6897]
# Permuation CV Scores: [0.7044, 0.7044, 0.7478, 0.7134, 0.7044]
# Permutation Test p-values: [1.0, 1.0, 0.005, 0.0589, 1.0]
#
# === Summary of Results ===
# SimpleLogisticRegression: Mean train score = 0.8052, Mean test score = 0.7448, Mean CV score = 0.7009, Permutation scores = 0.6411 +/- 0.0021, Mean p-value = 0.1149
# L1LogisticRegression: Mean train score = 0.7461, Mean test score = 0.6897, Mean CV score = 0.7150, Permutation scores = 0.6867 +/- 0.0217, Mean p-value = 0.6064
# L2LogisticRegression: Mean train score = 0.7525, Mean test score = 0.7103, Mean CV score = 0.7252, Permutation scores = 0.6918 +/- 0.0103, Mean p-value = 0.4146
# ElasticNet: Mean train score = 0.7594, Mean test score = 0.7034, Mean CV score = 0.7271, Permutation scores = 0.6874 +/- 0.0227, Mean p-value = 0.4066
# RandomForestClassifier: Mean train score = 0.8864, Mean test score = 0.6828, Mean CV score = 0.7267, Permutation scores = 0.6701 +/- 0.0255, Mean p-value = 0.1984
# SupportVectorClassifier: Mean train score = 0.7618, Mean test score = 0.6897, Mean CV score = 0.7149, Permutation scores = 0.6926 +/- 0.0145, Mean p-value = 0.6128

# %%
# make summary plot
plt.figure(figsize=(8,4))
bars = plt.bar(algorithms, mean_scores, yerr=stddev_scores, capsize=5, alpha=0.7)

plt.xlabel('Algorithms')
plt.ylabel('Accuracy (Mean Test Score)')
plt.title('Model Performance (Accuracy)')
plt.xticks(rotation=45)

for bar, mean in zip(bars, mean_scores):
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height / 2,                # center vertically
        f"{mean:.3f}",
        ha='center',
        va='center',
        color='black',   
        fontsize=9,
    )

plt.savefig(f"../../figures/{response_var}_dyna_bp_accuracy.png", format="png", dpi=300)
plt.show()

# %%
# generate permutation plots
# plot_permutation_results(perm_plot_data, "MDD Remitter")
title_suffix = f"MDD {response_var_cap}"
for model_name, (cv_scores, perm_scores_list, p_values) in perm_plot_data.items():

        cv_score = np.mean(cv_scores)
        perm_scores = np.concatenate(perm_scores_list)
        p_value = np.mean(p_values)

        plt.figure(figsize=(6,4))
        plt.hist(perm_scores, bins=20, density=True, label="Permutation scores")

        plt.axvline(
            cv_score,
            ls="--",
            color="r",
            label=f"Mean score on original data = {cv_score:.2f}\n(p = {p_value:.3f})"
        )

        plt.legend(fontsize=8)
        plt.xlabel("Accuracy score")
        plt.ylabel("Probability density")
        plt.title(f"Permutation Scores: {model_name} ({title_suffix})")

        plt.show()

# %% [markdown]
# ### Interpretability

# %%
file = open(f'../../results/mdd_dyna_bp/SimpleLogisticRegression_accuracy_{response_var}.save', 'rb')
best_models, test_scores = pickle.load(file)
file.close()

# get best model
top_one_index = np.argsort(test_scores)[-1:][0]  
best_model = best_models[top_one_index]
best_model
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('onehot',
#                                                   Pipeline(steps=[('imputer0',
#                                                                    SimpleImputer(strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['gender',
#                                                    'ever_used_drugs']),
#                                                  ('std',
#                                                   Pipeline(steps=[('imputer2',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'education',
#                                                    'BDI_pre', 'bp_PC1',
#                                                    'bp_PC2', 'bp_PC3', 'bp_PC4',
#                                                    'bp_PC5', 'dyna_PC1',
#                                                    'dyna_PC2', 'dyna_PC3',
#                                                    'dyna_PC4', 'dyna_PC5'])])),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000000, solver='saga'))])

# %%
feat_imp = interpretability.get_logreg_feature_importance(best_model)
interpretability.plot_logreg_feature_importance(feat_imp)

# %%
# display confusion matrix
class_labels = [f"Non-{response_var_cap}", response_var_cap]
# plot_confusion_matrix(best_model, X_test, y_test, class_labels)
model = best_model
title = "Confusion Matrix"
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)

# normalize
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

disp = ConfusionMatrixDisplay(confusion_matrix=cm_norm, display_labels=class_labels)
disp.plot(values_format='.3f', cmap=plt.cm.Blues)
plt.title(title)
plt.show()
