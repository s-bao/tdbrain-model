# %%
import pandas as pd

# %%
pd.read_csv('../results/all_diff_region_perm/merged_channel_sweep_results.csv')
# Out:
#    combo_name            channels  n_channels                model_name  \
# 0       perm4  Fp2,F3,C4,T8,P8,O1           6      L2LogisticRegression
# 1       perm3         F7,T7,Pz,O1           4  SimpleLogisticRegression
# 2       perm3         F7,T7,Pz,O1           4      L2LogisticRegression
# 3       perm3         F7,T7,Pz,O1           4                ElasticNet
# 4   informed1         F7,Cz,P8,O2           4  SimpleLogisticRegression
# 5       perm4  Fp2,F3,C4,T8,P8,O1           6  SimpleLogisticRegression
# 6   informed3        Fz,FCz,Pz,Oz           4  SimpleLogisticRegression
# 7       perm4  Fp2,F3,C4,T8,P8,O1           6                ElasticNet
# 8       perm3         F7,T7,Pz,O1           4      L1LogisticRegression
# 9   informed2        F8,FC4,P8,O2           4  SimpleLogisticRegression
# 10  informed3        Fz,FCz,Pz,Oz           4   SupportVectorClassifier
# 11  informed1         F7,Cz,P8,O2           4      L1LogisticRegression
# ...
